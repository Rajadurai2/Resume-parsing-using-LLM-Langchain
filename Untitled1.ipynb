# %%
from kor.extraction import create_extraction_chain
from kor.nodes import Object, Text, Number

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import TextConverter
import io

# %%
api_key = "AIzaSyA9oNzA2KZdFJrQRlr3nV_cc-_QakneJEI"

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro", google_api_key=api_key)

# %%
def pdf_reader(file):
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
    with open(file, 'rb') as fh:
        for page in PDFPage.get_pages(fh,
                                      caching=True,
                                      check_extractable=True):
            page_interpreter.process_page(page)
            print(page)
        text = fake_file_handle.getvalue()

    # close open handles
    converter.close()
    fake_file_handle.close()
    return text

# %%
def parse_data(llm,resume_text):
        # Define the prompt template for parsing resumes
    # resume_parsing_prompt = PromptTemplate(
    #     input_variables=["resume_text"],
    #     template="Parse the following resume and extract person details,relevant skills, experiences, and qualifications:\n\n{resume_text}\n\nOutput as JSON."
    # )
    from langchain_core.output_parsers import JsonOutputParser

    output_parser = JsonOutputParser()
    resume_parsing_prompt = PromptTemplate(
    input_variables=["resume_text"],
    template=(
        "Parse the following resume and extract the person details, relevant skills, experiences, and qualifications. "
        "Ensure the output is a JSON object with the following keys: "
        "'personDetails', 'skills', 'experiences', 'certifications','qualifications','achievements','projects','hobbies'. "
        "If a field is not available, return it as an empty string or an empty list.\n\n"
        "{resume_text}\n\n"
        "Output as dict with the specified keys."
    )
)

    parsing_chain = LLMChain(llm=llm, prompt=resume_parsing_prompt,output_parser=output_parser)
    parsed_data = parsing_chain.run({"resume_text": resume_text})
    #parsed_data = json.loads("".join(parsed_data.split("\n")[1:-1]))
    return parsed_data

# %%
text = pdf_reader("uploads/CV_Han.pdf")
# Out:
# <PDFPage: Resources={'Font': {'F1': <PDFObjRef:5>, 'F2': <PDFObjRef:9>, 'F3': <PDFObjRef:11>, 'F4': <PDFObjRef:13>, 'F5': <PDFObjRef:18>, 'F6': <PDFObjRef:23>}, 'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'Font': {'F2': <PDFObjRef:9>, 'F3': <PDFObjRef:11>, 'F4': <PDFObjRef:13>, 'F1': <PDFObjRef:5>, 'F7': <PDFObjRef:27>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'Font': {'F3': <PDFObjRef:11>, 'F2': <PDFObjRef:9>, 'F4': <PDFObjRef:13>, 'F1': <PDFObjRef:5>, 'F7': <PDFObjRef:27>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'Font': {'F2': <PDFObjRef:9>, 'F3': <PDFObjRef:11>, 'F4': <PDFObjRef:13>, 'F1': <PDFObjRef:5>, 'F7': <PDFObjRef:27>, 'F5': <PDFObjRef:18>}, 'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'Font': {'F7': <PDFObjRef:27>, 'F1': <PDFObjRef:5>, 'F3': <PDFObjRef:11>, 'F4': <PDFObjRef:13>, 'F2': <PDFObjRef:9>, 'F5': <PDFObjRef:18>}, 'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'Font': {'F2': <PDFObjRef:9>, 'F4': <PDFObjRef:13>, 'F1': <PDFObjRef:5>, 'F3': <PDFObjRef:11>, 'F7': <PDFObjRef:27>, 'F5': <PDFObjRef:18>}, 'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'Font': {'F4': <PDFObjRef:13>, 'F1': <PDFObjRef:5>, 'F3': <PDFObjRef:11>, 'F7': <PDFObjRef:27>, 'F2': <PDFObjRef:9>, 'F6': <PDFObjRef:23>}, 'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>
# <PDFPage: Resources={'ExtGState': {'GS7': <PDFObjRef:7>, 'GS8': <PDFObjRef:8>}, 'Font': {'F2': <PDFObjRef:9>, 'F3': <PDFObjRef:11>, 'F8': <PDFObjRef:45>, 'F6': <PDFObjRef:23>}, 'ProcSet': [/'PDF', /'Text', /'ImageB', /'ImageC', /'ImageI']}, MediaBox=[0, 0, 595.32, 841.92]>

# %%
data = parse_data(llm,text)

# %%
pprint(data)
# Out:
# {'experiences': [{'achievements': ['Lead and manage Application Development '
#                                    'and Support Services',
#                                    '❖ Lottery products enhancements.',
#                                    'Participated and support pre-sales '
#                                    'activities'],
#                   'company': 'Hand Global Solutions Pte Ltd',
#                   'duration': 'Nov 2023 to July 2024',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Lead and manage Application Maintenance '
#                                    'and Support Services',
#                                    '❖ NEA Business Intelligence System(BIS) '
#                                    '(Microsoft SSIS and QlikSense)',
#                                    '❖ Go-Ahead (Singapore) BC Click',
#                                    'Participated and support pre-sales '
#                                    'activities'],
#                   'company': 'StarHub Limited',
#                   'duration': 'Apr 2022 to Nov 2023',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Lead and manage Application Development, '
#                                    'Maintenance and Support Services',
#                                    '❖ MCI iConnect & Content Website Platform '
#                                    '(CWP) using Sitecore',
#                                    '❖ CPIB SharePoint & Application',
#                                    '❖ AGC SharePoint & .NET Applications',
#                                    '❖ HDB 1CRM PoC',
#                                    'Participated and support pre-sales '
#                                    'activities',
#                                    'Participated in PMO setup, standardize & '
#                                    'simplify Project Methodology & Processes',
#                                    'Certified Scrum Master'],
#                   'company': 'Xtremax Pte Ltd',
#                   'duration': 'Nov 2019 to Mar 2022',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Lead and manage Application Maintenance '
#                                    'and Support Services',
#                                    '❖ Nanyang Technological University (NTU) '
#                                    '(ITIL processes using ServiceOne)',
#                                    '❖ National Panasonic (Data Analytic using '
#                                    'and Microsoft SSIS and PowerBI)',
#                                    'Participated and support pre-sales '
#                                    'activities'],
#                   'company': 'Fujitsu Asia Pte Ltd',
#                   'duration': 'Dec 2018 to Oct 2019',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Lead and manage High Focus Project on '
#                                    'Digital Government Transformation (DGT) '
#                                    'for Government of Fiji using Agile '
#                                    'Methodology for below modules :',
#                                    '❖ digitalFIJI (Mobile App)',
#                                    '❖ Directory@Gov',
#                                    '❖ MyFeedback',
#                                    '❖ FRCS Mobile Application and FNPF Mobile '
#                                    'Application',
#                                    '❖ Company Registration',
#                                    '❖ Common Services',
#                                    'Participated in working level committee to '
#                                    'support for digitalFIJI DGT Programme for '
#                                    'Mobile, Merchant & Delivery application '
#                                    'development.',
#                                    'Instrumental to adopt and establish the '
#                                    'Agile Methodology for incremental product '
#                                    'releases to mitigate against gaps due to '
#                                    're-prioritisation changes during delivery '
#                                    'timescale. Improve collaborative '
#                                    'engagement between cross-functional teams '
#                                    'to enhance final product functionalities.',
#                                    'Merchants:',
#                                    '▪ e-Profile',
#                                    '▪ e-Authentication',
#                                    '▪ e-Payment',
#                                    'rollout to Fiji citizens'],
#                   'company': 'CrimsonLogic Pte Ltd',
#                   'duration': 'Jan 2018 to Nov 2018',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Managed Development Team',
#                                    '❖ KouFu',
#                                    '❖ Boon Tong Kee',
#                                    '❖ Five Star Hainanese Chicken Rice',
#                                    '❖ Old Tea Hut',
#                                    '❖ Wolf Express',
#                                    '❖ Tiong Bahru Bakery',
#                                    '❖ Miam Miam',
#                                    '❖ Rollie Olie',
#                                    '❖ Aloha Poke',
#                                    '❖ Li Xin',
#                                    '❖ Brawn & Brains',
#                                    '❖ Tang Tea House',
#                                    '❖ FoodCity',
#                                    'Managed L2 and L3 activities'],
#                   'company': 'Applied Mesh Pte Ltd',
#                   'duration': 'Jul 2016 to Jan 2018',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Managed TPLinux Projects and Maintenance',
#                                    '❖ Carrefour (Taiwan)',
#                                    '❖ Wellcom (Taiwan)',
#                                    '❖ Aeon BIG (Malaysia)',
#                                    '❖ Econsave (Malaysia)',
#                                    '❖ Future Group (India)',
#                                    'Managed TPOMM & TP.net Migration Project',
#                                    'Managed and completed TPLinux migration '
#                                    'project for Carrefour Taiwan',
#                                    'Participated in PMO to setup, standardize '
#                                    '& simplify Project Methodology & Processes',
#                                    'Participated and support pre-sales '
#                                    'activities'],
#                   'company': 'Wincor Nixdorf Pte Ltd',
#                   'duration': 'Oct 2010 to Jun 2016',
#                   'role': 'Project Manager',
#                   'title': 'Project Manager'},
#                  {'achievements': ['Assigned to provide leadership for '
#                                    'CitiBank Security Fund Systems when 3 of '
#                                    'the 4 team leads left in Oct to Dec 2007. '
#                                    'This system consists mainly of 2 '
#                                    'applications deployed for 13 countries '
#                                    '(AU, NZ, CN, HK, TW, KR, VN, TH, MY, PH, '
#                                    'SG, ID, IN). Billing is a redesign project '
#                                    'to re-engineering to merge the Hong Kong & '
#                                    'Regional Billing system and to improve the '
#                                    'billing engine performance and capacity. '
#                                    'COPES (Custody Operation Productivity '
#                                    'Enhancement Server) is Citibank’s Global '
#                                    'Securities Services to process securities '
#                                    'transactions of Customers. COPES is a '
#                                    'migration project to web-enable the '
#                                    'application on .NET platform. It consists '
#                                    'of of 4 different sub-systems interfacing '
#                                    'with each other:',
#                                    '❖ Promoted the remaining team lead and '
#                                    'worked with Service Delivery Director to '
#                                    'revised package',
#                                    '❖ Transferred 2 team members from '
#                                    'Production Support Team to Development '
#                                    'Support Team to ensure domain knowledge '
#                                    'continuity and stability',
#                                    '❖ Oversee the migration from VB6 to .NET '
#                                    'C# web-based technologies. Existing '
#                                    'client-server technology is also replaced '
#                                    'by web technology for ease of '
#                                    'maintainability and provides scalability. '
#                                    'In the course of migration, leads effort '
#                                    'to identify, propose, implement and '
#                                    'resolve performance bottlenecks',
#                                    '❖ Manage a local team size of 20+, '
#                                    'consisting of team leads and developers. '
#                                    'In addition, outsource to around 20 '
#                                    'offshore developers in Malaysia, Suzhou '
#                                    'and Chengdu',
#                                    'Lead and assist Seylan Bank (Pvt) Ltd, Sri '
#                                    'Lanka to establish a Project Management '
#                                    'Office (PMO) to support IT-based projects',
#                                    '❖ Set up a process to help SB to '
#                                    'prioritize, maximize and balance IT '
#                                    'Project investment. The process will '
#                                    'facilitate the prioritization of projects '
#                                    'based on the IT budget, cost/benefits, '
#                                    'associated risk, alignment with SB '
#                                    'strategic business goals/needs and the '
#                                    'availability of IT resources, etc',
#                                    '❖ Coordinated centralized tracking and '
#                                    'reporting of project progress, in order to '
#                                    'provide a single and consolidated view of '
#                                    'projects status to management',
#                                    '❖ Defined and championed project '
#                                    'management practices to continuously '
#                                    'improve the consistency and effectiveness '
#                                    'of how projects are managed, including '
#                                    'appropriate consideration of risk',
#                                    '❖ Enhanced the competence and skill of PM '
#                                    'through training, coaching and mentoring',
#                                    '❖ Facilitated IT reorganization',
#                                    'Other projects include:',
#                                    '❖ Participated in pre-sales and scope '
#                                    'definition for Abacus FareX system',
#                                    '❖ Applied Biosystems Application '
#                                    'Outsourcing',
#                                    ''],
#                   'company': 'National Computer Systems Pte Ltd',
#                   'duration': 'Oct 2006 to Sep 2010',
#                   'role': 'Project Manager',
#                   'title': 'Senior Consultant'}],
#  'personDetails': {'availability': 'Short Notice',
#                    'dateOfBirth': '23 March 1970',
#                    'email': 'han8843@gmail.com',
#                    'gender': 'Male',
#                    'hobby': 'Watch Soccer',
#                    'maritalStatus': 'Married',
#                    'mobile': '65-90236263',
#                    'name': 'Han Chee Chew',
#                    'nationality': 'Singaporean'},
#  'skills': ['Ability in project scoping, budgeting, planning, execution, '
#             'monitoring and resource balancing skills',
#             'Have in-depth knowledge and practical experience in Software '
#             'Development Life Cycle (SDLC) from project inception, '
#             'elaboration, construction to transition state for large-scale '
#             'project',
#             'Proven analytical with good technical background',
#             'Coordinating, negotiating and motivating cross functional project '
#             'team in support of schedule and IT project deliverables',
#             'Training, motivating and mentoring on-site and offshore junior '
#             'project managers, software engineers and quality assurance '
#             'specialists',
#             'Ability to communicate with stakeholders to provide '
#             'information/report regarding the ongoing projects and '
#             'initiatives, including aspect of risk and quality',
#             'Form trusting relationships, establishing rapport and respect '
#             'with clients',
#             'Experienced in offshore Software Development Center (SDC) '
#             'operation management',
#             'Agile Methodology – Certified Scrum Master',
#             'Have experience in Digital Transformation & Cloud Technologies']}

# %%
data.keys()
# Out:
# dict_keys(['personDetails', 'skills', 'experiences'])

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser

output_parser = JsonOutputParser()

prompt = PromptTemplate(
    input_variables=["wood","actor_name"],
    template = '''Give some {wood} movie details acted by {actor_name} in dict''' 
    
)

chain = LLMChain(llm=llm,prompt=prompt,output_parser=output_parser)
summa = chain.run(
    {
        "wood": "Kollywood",
        "actor_name": "vijay",
    }
)

# %%
print(summa)
# Out:
# {'Vijay_Movies': [{'Movie Title': 'Thuppakki', 'Release Year': 2012, 'Role': 'Jaguar', 'Director': 'A. R. Murugadoss'}, {'Movie Title': 'Jilla', 'Release Year': 2014, 'Role': 'Shiva & Shakti', 'Director': 'R. T. Neason'}, {'Movie Title': 'Kaththi', 'Release Year': 2014, 'Role': 'Kathiresan & Jeevanandham', 'Director': 'A. R. Murugadoss'}, {'Movie Title': 'Puli', 'Release Year': 2015, 'Role': 'Marudheeran & Pulivendhan', 'Director': 'Chimbu Deven'}, {'Movie Title': 'Theri', 'Release Year': 2016, 'Role': 'Dharmeshwar', 'Director': 'Atlee Kumar'}, {'Movie Title': 'Bairavaa', 'Release Year': 2017, 'Role': 'Bairavaa', 'Director': 'Bharathan'}, {'Movie Title': 'Mersal', 'Release Year': 2017, 'Role': 'Maaran, Vetri, & Thalaivar', 'Director': 'Atlee Kumar'}, {'Movie Title': 'Sarkar', 'Release Year': 2018, 'Role': 'Sundar Ramasamy', 'Director': 'A. R. Murugadoss'}, {'Movie Title': 'Bigil', 'Release Year': 2019, 'Role': 'Michael & Rayappan', 'Director': 'Atlee Kumar'}, {'Movie Title': 'Master', 'Release Year': 2021, 'Role': 'John Durairaj', 'Director': 'Lokesh Kanagaraj'}, {'Movie Title': 'Beast', 'Release Year': 2022, 'Role': 'Veera Raghavan', 'Director': 'Nelson Dilipkumar'}, {'Movie Title': 'Varisu', 'Release Year': 2023, 'Role': 'Vijay Rajendran', 'Director': 'Vamshi Paidipally'}]}
